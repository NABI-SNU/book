# %% [markdown]
# # Intro

# %% [markdown]
# ## Warm-up Problems

# %% [markdown]
# **Problem 1. Observable vs. Hidden State**
#
# 다음은 한 대학생에 대한 이야기이다.
#
# 민수는 최근 동아리 모임에 거의 나오지 않는다. 단톡방에서는 답장이 늦어졌고, 평소보다 말수도 확연히 줄었다. 새벽 늦게까지 게임을 하며 온라인에 접속하는 날이 많아졌으며, 수업 시간에는 자주 멍하게 창밖을 바라본다. 친구들은 민수가 많이 지쳐 보인다고 이야기한다. 실제로 민수는 중요한 시험과 진로 문제 때문에 큰 스트레스를 받고 있다고 느끼고 있다.
#
# Q1-1. 위 이야기 속 정보를 다음 두 범주로 나누시오.
#
# 1.  직접 관찰 가능한 정보:
#
# 2.  직접 관찰하기 어렵고, 추론이 필요한 상태:
#
# 3.  (A)와 (B)로 명확하게 분류하기 어려운 애매한 표현:
#
# Q1-2. (A)에 해당하는 정보만을 가지고 민수의 상태를 이해할 수 있는가? 그 이유는?

# %% [markdown]
# **Problem 2. 하나의 Hidden State는 여러 행동을 만든다**
#
# 다음은 시험 기간의 대학생의 모습을 나열한 것이다.
#
# 커피를 자주 마신다, 예민해진다, 잠이 줄었다, SNS 활동이 줄었다 …
#
# Q2-1. 위 행동들은 서로 독립적인가요? 그 이유는?
#
# Q2-2. 위 행동들을 설명할 수 있는 latent factor에는 무엇이 있는가?
#
# Q2-3. Q2-2에서 답한 latent factor는 직접 관측 가능한가? 그렇지 않다면 무엇을 보고 추론하고 있는가?

# %% [markdown]
# **Problem 3. Temporal Dynamics, Ambiguity of Inference**
#
# 다음은 한 학생의 하루 동안 행동 변화이다.
#
# | **시간**  | **행동**                              |
# |-----------|---------------------------------------|
# | 오전 9시  | 집중해서 공부함                       |
# | 오전 11시 | 휴대폰 확인이 잦아짐                  |
# | 오후 1시  | 멍하게 화면을 바라봄                  |
# | 오후 3시  | 유튜브를 보기 시작함                  |
# | 오후 5시  | 책상에 앉아 있지만 거의 공부하지 못함 |
#
# Q3-1. 각 시간대에서 학생의 hidden state를 추론 해보시오. (ex. 집중, 피로, 지루함 …)
#
# Q3-2. 학생의 상태는 매 순간 랜덤하게 바뀌는가? 아니면 현재 상태는 이전 상태의 영향을 받으며 점진적으로 변하는가?
#
# Q3-3. 위 행동 변화는 일반적으로 점점 피곤해지는 상태 때문에 나타난다고 해석할 수 있다. 하지만, 오전 11시에 친구와의 갈등으로 인해 기분이 나빠져서 공부를 못했을 수 있으며, 시험의 불안 때문에 점점 집중을 못했을 수도 있다. 이때, 학생의 실제 상태를 알기 위해서는 어떤 정보들이 추가로 필요한가?

# %% [markdown]
# **Problem 3. Temporal Dynamics, Ambiguity of Inference**
#
# 다음은 한 학생의 하루 동안 행동 변화이다.
#
# | **시간**  | **행동**                              |
# |-----------|---------------------------------------|
# | 오전 9시  | 집중해서 공부함                       |
# | 오전 11시 | 휴대폰 확인이 잦아짐                  |
# | 오후 1시  | 멍하게 화면을 바라봄                  |
# | 오후 3시  | 유튜브를 보기 시작함                  |
# | 오후 5시  | 책상에 앉아 있지만 거의 공부하지 못함 |
#
# Q3-1. 각 시간대에서 학생의 hidden state를 추론 해보시오. (ex. 집중, 피로, 지루함 …)
#
# Q3-2. 학생의 상태는 매 순간 랜덤하게 바뀌는가? 아니면 현재 상태는 이전 상태의 영향을 받으며 점진적으로 변하는가?
#
# Q3-3. 위 행동 변화는 일반적으로 점점 피곤해지는 상태 때문에 나타난다고 해석할 수 있다. 하지만, 오전 11시에 친구와의 갈등으로 인해 기분이 나빠져서 공부를 못했을 수 있으며, 시험의 불안 때문에 점점 집중을 못했을 수도 있다. 이때, 학생의 실제 상태를 알기 위해서는 어떤 정보들이 추가로 필요한가?
